# %% [markdown]
# <a href="https://colab.research.google.com/github/vishal00880/summer-git/blob/main/data%20frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_csv("/content/titanic - titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 37           929         1       3                         Cacic, Miss. Manda
# 249         1141         1       3  Khalil, Mrs. Betros (Zahie Maria" Elias)"
# 243         1135         0       3                         Hyman, Mr. Abraham
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 37   female  21.0      0      0  315087   8.6625   NaN        S
# 249  female   NaN      1      0    2660  14.4542   NaN        C
# 243    male   NaN      0      0    3470   7.8875   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.iloc[2:5,[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
p=df.dropna()
p.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df=df.drop(columns=['Cabin'])

# %%
df['Fare']=df['Fare'].fillna(5)

# %%
df['Age']=df['Age'].fillna(10)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['Fare'].dtype
# Out:
# dtype('float64')

# %%
df['Fare']=df['Fare'].astype('int')

# %%
df['Fare'].dtype
# Out:
# dtype('int64')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket  Fare Embarked
# 0  34.5      0      0  330911     7        Q
# 1  47.0      1      0  363272     7        S
# 2  62.0      0      0  240276     9        Q

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df=df.rename(columns={"Age":"updated_Age"})

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#    update_Age  SibSp  Parch  Ticket  Fare Embarked
# 0        34.5      0      0  330911     7        Q
# 1        47.0      1      0  363272     7        S
# 2        62.0      0      0  240276     9        Q

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'update_Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
from enum import auto
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df = pd.read_csv("/content/tips - tips.csv")

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.scatterplot( x = df['total_bill'],
                 y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot( x ="total_bill",y="tip",data=df,hue =df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot( x ="total_bill",
                y="tip",data=df,
                hue =df['sex'],style=df['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
p = pd.crosstab(df['day'],df['time'])
p
# Out:
# time  Dinner  Lunch
# day
# Fri       12      7
# Sat       87      0
# Sun       76      0
# Thur       1     61

# %%
sns.heatmap(p)
# Out:
# <Axes: xlabel='time', ylabel='day'>

# %%
df.groupby('time')['total_bill'].sum()
# Out:
# time
# Dinner    3660.30
# Lunch     1167.47
# Name: total_bill, dtype: float64

# %%
df.groupby('tip').sum('tip')
# Out:
#        total_bill  size
# tip
# 1.00        28.67     6
# 1.01        16.99     2
# 1.10        12.90     2
# 1.17        32.83     2
# 1.25        29.09     6
# ...           ...   ...
# 6.70        34.30     6
# 6.73        48.27     4
# 7.58        39.42     4
# 9.00        48.33     4
# 10.00       50.81     3
#
# [123 rows x 2 columns]

# %%
df.groupby('sex').sum('tip')
# Out:
#         total_bill     tip  size
# sex
# Female     1570.95  246.51   214
# Male       3256.82  485.07   413

# %%
df.groupby('sex').max('tip')
# Out:
#         total_bill   tip  size
# sex
# Female       44.30   6.5     6
# Male         50.81  10.0     6

# %%
df.groupby('sex').max()['tip'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='tip'>
